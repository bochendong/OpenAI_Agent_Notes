# %% [markdown]
# # Summary Agent 测试
#
# 测试章节总结生成器的功能

# %%
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd())))

from agents import Runner
from SummaryCreator.summaryAgent import summary_agent

# %% [markdown]
# ## Test 1: 数学章节总结（理科）

# %%
response = await Runner.run(summary_agent, "生成关于函数定义域和值域这一章节的总结")

# %%
print(response.final_output)

# %% [markdown]
# ## Test 2: 社会学章节总结（文科）

# %%
response = await Runner.run(summary_agent, "生成关于社会化这一章节的总结，包括社会化的定义、类型、影响因素和意义")

# %%
print(response.final_output)

# %% [markdown]
# ## Test 3: 心理学章节总结（文科）

# %%
response = await Runner.run(summary_agent, "生成关于认知失调理论这一章节的总结，包括理论内容、实验研究和应用")

# %%
print(response.final_output)
