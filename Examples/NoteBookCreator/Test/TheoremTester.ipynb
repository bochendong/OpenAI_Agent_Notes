# %% [markdown]
# # Theorem Agent 测试
#
# 测试定理生成器的功能

# %%
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd())))

from agents import Runner
from TheoremCreator.theoremAgent import theorem_agent

# %% [markdown]
# ## Test 1: 数学定理（理科）

# %%
response = await Runner.run(theorem_agent, "生成中值定理的定理陈述和证明")

# %% [markdown]
# ## Test 2: 心理学理论/原理（文科）

# %%
response = await Runner.run(theorem_agent, "生成认知失调理论的原理陈述和理论解释")

# %%
print("理论/原理:")
print(response.final_output.theorem)
print("\n理论解释/论证:")
print(response.final_output.proof)
print("\n完整输出:")
print(response.final_output)

# %%
print("定理:")
print(response.final_output.theorem)
print("\n证明:")
print(response.final_output.proof)
print("\n完整输出:")
print(response.final_output)
# Out:
# 定理:
# 设函数 f(x) 在闭区间 [a, b] 上连续，并在开区间 (a, b) 上可导，则存在 ξ ∈ (a, b)，使得
# f'(ξ) = \frac{f(b) - f(a)}{b - a}。
#
# 证明:
# 证明：
# 设 F(x) = f(x) - \frac{f(b) - f(a)}{b - a} (x-a)。
# 1. 由于 f(x) 在 [a, b] 上连续且在 (a, b) 上可导，函数 x \mapsto \frac{f(b) - f(a)}{b - a} (x-a) 显然在 [a, b] 上连续且在 (a, b) 上可导，因此 F(x) 在 [a, b] 上连续，在 (a, b) 上可导。
# 2. 计算 F 在端点的值：
#    F(a) = f(a) - 0 = f(a)
#    F(b) = f(b) - \frac{f(b) - f(a)}{b - a} (b-a) = f(b) - [f(b)-f(a)] = f(a)
#    所以 F(a) = F(b)
# 3. 根据罗尔定理，存在 ξ ∈ (a, b)，使得 F'(ξ) = 0。
# 4. 计算 F'(x)：
#    F'(x) = f'(x) - \frac{f(b) - f(a)}{b - a}
#    由 F'(ξ) = 0，有 f'(ξ) - \frac{f(b) - f(a)}{b - a} = 0，
#    即 f'(ξ) = \frac{f(b) - f(a)}{b - a}。
#
# 证毕。
#
# 完整输出:
# ...
