# %% [markdown]
# # Definition Agent 测试
#
# 测试定义生成器的功能

# %%
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd())))

from agents import Runner
from DefinitionCreator.definationAgent import definition_agent

# %% [markdown]
# ## Test 1: 数学

# %%
response = await Runner.run(definition_agent, "生成函数定义域的定义")

# %%
print("定义:")
print(response.final_output.definition)
print("\n完整输出:")
print(response.final_output)
# Out:
# 定义:
# 函数的定义域是指使函数表达式有意义（即函数值存在）的自变量x的所有取值所构成的集合。
#
# 完整输出:
# definition_id=None definition='函数的定义域是指使函数表达式有意义（即函数值存在）的自变量x的所有取值所构成的集合。'

# %% [markdown]
# ## Test 2: 编程概念定义

# %%
response = await Runner.run(definition_agent, "生成递归函数的定义")

# %%
print("定义:")
print(response.final_output.definition)
print("\n完整输出:")
print(response.final_output)
# Out:
# 定义:
# 递归函数是指在其定义或求解过程中直接或间接调用自身的函数，通常包括一个或多个基例（终止条件）和递归调用部分，用于将复杂问题分解为相同类型的子问题逐步求解。
#
# 完整输出:
# definition_id=None definition='递归函数是指在其定义或求解过程中直接或间接调用自身的函数，通常包括一个或多个基例（终止条件）和递归调用部分，用于将复杂问题分解为相同类型的子问题逐步求解。'

# %% [markdown]
# ## Test 3: 社会学概念定义

# %%
response = await Runner.run(definition_agent, "生成社会化的定义")

# %%
print("定义:")
print(response.final_output.definition)
print("\n完整输出:")
print(response.final_output)
# Out:
# 定义:
# 社会化是指个体在社会生活过程中，通过与社会环境及他人的互动，逐步学习和内化社会规范、价值观、行为准则及技能，从而成为社会成员的过程。
#
# 完整输出:
# definition_id=None definition='社会化是指个体在社会生活过程中，通过与社会环境及他人的互动，逐步学习和内化社会规范、价值观、行为准则及技能，从而成为社会成员的过程。'

# %% [markdown]
# ## Test 4: 心理学概念定义

# %%
response = await Runner.run(definition_agent, "生成认知失调的定义")

# %%
print("定义:")
print(response.final_output.definition)
print("\n完整输出:")
print(response.final_output)
# Out:
# 定义:
# 认知失调（Cognitive Dissonance）是指个体在同时持有两种或两种以上相互矛盾的认知（如信念、态度、价值观或行为）时所体验到的不愉快的心理紧张状态。该理论由美国心理学家莱昂·费斯廷格提出，认为个体会倾向于通过改变认知或行为来减少失调，从而恢复心理平衡。
#
# 完整输出:
# definition_id=None definition='认知失调（Cognitive Dissonance）是指个体在同时持有两种或两种以上相互矛盾的认知（如信念、态度、价值观或行为）时所体验到的不愉快的心理紧张状态。该理论由美国心理学家莱昂·费斯廷格提出，认为个体会倾向于通过改变认知或行为来减少失调，从而恢复心理平衡。'
